# %% [markdown]
# # **COLAB 使用 Linux 指令**

# %%
# !pwd
# !ls
#!pip3 list
# Out:
# /content/gdrive/My Drive/Colab Notebooks
#  ColabTest.ipynb
# 'Copy of Keras Fashion MNIST'
# 'Copy of Welcome To Colaboratory'
# 'Copy of 如何使用自有資料集訓練在 Colab 上訓練 YOLO 物件辨識.ipynb'
#  HR_comma_sep.csv
#  R7_16_3_Kmeans_鳶尾花.ipynb
#  S2_整體學習_Voting_Bagging_RandomForest.ipynb
#  transfer_learning.ipynb
# 'Yolov3 using Darnet on Colab.ipynb'

# %% [markdown]
# # **載入Google Drive 設在虛擬機器硬碟 /app**

# %%
# Mount Google Drive as folder 
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -fs /content/gdrive/My\ Drive /app
# !pwd
# !ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/app/My Drive': Input/output error
# /content/gdrive/My Drive/Colab Notebooks
#  ColabTest.ipynb
# 'Copy of Keras Fashion MNIST'
# 'Copy of Welcome To Colaboratory'
# 'Copy of 如何使用自有資料集訓練在 Colab 上訓練 YOLO 物件辨識.ipynb'
#  HR_comma_sep.csv
#  R7_16_3_Kmeans_鳶尾花.ipynb
#  S2_整體學習_Voting_Bagging_RandomForest.ipynb
#  transfer_learning.ipynb
# 'Yolov3 using Darnet on Colab.ipynb'

# %%
# Test2 : Colab 下, 使用 !cd 有時會有問題
# !cd /app/Data
# !pwd
# !ls
# Out:
# /content/gdrive/My Drive/Colab Notebooks
#  ColabTest.ipynb
# 'Copy of Keras Fashion MNIST'
# 'Copy of Welcome To Colaboratory'
# 'Copy of 如何使用自有資料集訓練在 Colab 上訓練 YOLO 物件辨識.ipynb'
#  HR_comma_sep.csv
#  R7_16_3_Kmeans_鳶尾花.ipynb
#  S2_整體學習_Voting_Bagging_RandomForest.ipynb
#  transfer_learning.ipynb
# 'Yolov3 using Darnet on Colab.ipynb'

# %%
# Test3 : Colab 下, 需使用 %cd 
# %cd /app/Colab\ Notebooks
# !pwd
# !ls
# Out:
# /content/gdrive/My Drive/Colab Notebooks
# /content/gdrive/My Drive/Colab Notebooks
#  ColabTest.ipynb
# 'Copy of Keras Fashion MNIST'
# 'Copy of Welcome To Colaboratory'
# 'Copy of 如何使用自有資料集訓練在 Colab 上訓練 YOLO 物件辨識.ipynb'
#  HR_comma_sep.csv
#  R7_16_3_Kmeans_鳶尾花.ipynb
#  S2_整體學習_Voting_Bagging_RandomForest.ipynb
#  transfer_learning.ipynb
# 'Yolov3 using Darnet on Colab.ipynb'

# %% [markdown]
# # **爬蟲程式測試**

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.taiwanlottery.com.tw/'
html = requests.get(url)
sp = BeautifulSoup(html.text, 'html.parser')

data1 = sp.select("#rightdown")
#print(data1)

data2 = data1[0].find('div', {'class':'contents_box02'})
#print(data2)

data3 = data2.find_all('div', {'class':'ball_tx'})
#print(data3)
#
# 威力彩號碼
print("開出順序：",end="")
for n in range(0,6):
    print(data3[n].text,end="  ") 

print("\n大小順序：",end="")    
for n in range(6,len(data3)):
    print(data3[n].text,end="  ")
     
## 第二區
red = data2.find('div', {'class':'ball_red'})        
print("\n第二區：{}".format(red.text))
# Out:
# 開出順序：13   14   04   03   05   06
# 大小順序：03   04   05   06   13   14
# 第二區：05
